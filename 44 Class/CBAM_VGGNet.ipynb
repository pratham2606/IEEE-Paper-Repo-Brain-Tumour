# %%
import os
import itertools

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout,BatchNormalization

import warnings
warnings.filterwarnings('ignore')

print("Modules Loaded")
# Out:
# Modules Loaded

# %%
import os
import cv2
import glob
import math
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import multiprocessing
import tensorflow as tf
from pathlib import Path
import concurrent.futures
import keras.backend as K
from time import perf_counter
from functools import lru_cache
import matplotlib.pyplot as plt
from keras import layers, models
from keras.optimizers import Adam
from PIL import Image, ImageEnhance
from joblib import Parallel, delayed
from collections import defaultdict, Counter
from sklearn.preprocessing import LabelEncoder
from keras.metrics import Precision, Recall, AUC
from keras.callbacks import LearningRateScheduler
from keras.utils import plot_model, to_categorical
from sklearn.model_selection import train_test_split
from concurrent.futures import ThreadPoolExecutor, as_completed
from sklearn.metrics import accuracy_score, classification_report

# %%
from keras.applications import VGG16

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Read data and store in df

# %%
def main(train_data_path):

    """
    return training and testing dataframes including 2 columns image path and its label

    Args:
      train_data_path (string): string includes your train data path
      test_data_path (string): string includes your test data path
      note: data_path argument must contains your classes dirs

    Returns:
      train_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the training images and the label of each image
      test_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the testing images and the label of each image

    """

    for dirs in [train_data_path]:

        filepaths = []
        labels = []
        classes_list = sorted(os.listdir(dirs))

        filepaths,labels = get_fileList(classes_list, dirs, filepaths, labels)

        train_df = obtain_train_df(filepaths, labels)


    return train_df



def get_fileList(classes_list, dirs, filepaths, labels):


    """
    return file paths list including all full image paths and label for each one

    Args:
      classes_list (list): list includes name of classes dirs
      dirs (string): the data path
      filepaths (list): empty list to fill with images paths later
      labels (list): empty list to fill with each image label later

    Returns:
      count (scalar):  number of images in your dataset
    """


    for s_class in classes_list:

        label = s_class
        classpath = os.path.join(dirs, s_class)
        flist = sorted(os.listdir(classpath))

        store_image_names_and_its_labels(flist, classpath, filepaths, labels, label)

    return filepaths, labels


def store_image_names_and_its_labels(flist, classpath, filepaths, labels, label):

    """
    return nothing, it fills the filepaths list with all the images paths and its labels

    Args:
      flist (list) : contains all the image names in certain class
      classes_list (list): list includes name of classes dirs
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset
      label (string): label for a specific image

    Returns:
      nothing
    """


    for file in flist:
        file_path = os.path.join(classpath, file)
        filepaths.append(file_path)
        labels.append(label)



def obtain_train_df(filepaths, labels):

    """
    Return Dataframe with 2 columns contains each image path with its label

    Args:
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset

    Returns:
      train_df (DataFrame):  Dataframe with 2 columns contains each image path with its label
    """

    train_df =pd.DataFrame({
        'image_path' : filepaths,
        'label' : labels
    })
    return train_df

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !pip -q install kagglehub

# %%
import kagglehub

# Download the dataset
path = kagglehub.dataset_download("fernando2rad/brain-tumor-mri-images-44c")

print("Dataset downloaded to:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/1.archive...
# 100%|██████████| 188M/188M [00:01<00:00, 112MB/s]
# Extracting files...
# Dataset downloaded to: /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1

# %%
import os

for root, dirs, files in os.walk(path):
    print(root)
# Out:
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Neurocitoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Schwannoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Ependimoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Neurocitoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Ependimoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Astrocitoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Tuberculoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Granuloma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Papiloma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Meduloblastoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Meningioma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Germinoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Schwannoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Ganglioglioma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Granuloma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Schwannoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Germinoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Glioblastoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Astrocitoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Tuberculoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Ganglioglioma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Meningioma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Glioblastoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/_NORMAL T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Tuberculoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Meduloblastoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Papiloma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Oligodendroglioma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Ependimoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Astrocitoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Carcinoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Germinoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Ganglioglioma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/_NORMAL T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Oligodendroglioma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Papiloma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Meningioma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Meduloblastoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Neurocitoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Granuloma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Glioblastoma T1C+
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Carcinoma T2
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Carcinoma T1
# /root/.cache/kagglehub/datasets/fernando2rad/brain-tumor-mri-images-44c/versions/1/Oligodendroglioma T1

# %%
data_dir = path
data_df = main(data_dir)

# %%
data_df.head()
# Out:
#                                           image_path           label
# 0  /root/.cache/kagglehub/datasets/fernando2rad/b...  Astrocitoma T1
# 1  /root/.cache/kagglehub/datasets/fernando2rad/b...  Astrocitoma T1
# 2  /root/.cache/kagglehub/datasets/fernando2rad/b...  Astrocitoma T1
# 3  /root/.cache/kagglehub/datasets/fernando2rad/b...  Astrocitoma T1
# 4  /root/.cache/kagglehub/datasets/fernando2rad/b...  Astrocitoma T1

# %%
# data_df = merge_classes(data_df)

# %%
data_df["label"].unique()
# Out:
# array(['Astrocitoma T1', 'Astrocitoma T1C+', 'Astrocitoma T2',
#        'Carcinoma T1', 'Carcinoma T1C+', 'Carcinoma T2', 'Ependimoma T1',
#        'Ependimoma T1C+', 'Ependimoma T2', 'Ganglioglioma T1',
#        'Ganglioglioma T1C+', 'Ganglioglioma T2', 'Germinoma T1',
#        'Germinoma T1C+', 'Germinoma T2', 'Glioblastoma T1',
#        'Glioblastoma T1C+', 'Glioblastoma T2', 'Granuloma T1',
#        'Granuloma T1C+', 'Granuloma T2', 'Meduloblastoma T1',
#        'Meduloblastoma T1C+', 'Meduloblastoma T2', 'Meningioma T1',
#        'Meningioma T1C+', 'Meningioma T2', 'Neurocitoma T1',
#        'Neurocitoma T1C+', 'Neurocitoma T2', 'Oligodendroglioma T1',
#        'Oligodendroglioma T1C+', 'Oligodendroglioma T2', 'Papiloma T1',
#        'Papiloma T1C+', 'Papiloma T2', 'Schwannoma T1', 'Schwannoma T1C+',
#        'Schwannoma T2', 'Tuberculoma T1', 'Tuberculoma T1C+',
#        'Tuberculoma T2', '_NORMAL T1', '_NORMAL T2'], dtype=object)

# %%
num_classes = len(data_df['label'].unique())
print(f"We have {num_classes} classes")
print(f"We have {data_df.shape[0]} images")
# Out:
# We have 44 classes
# We have 4479 images

# %%
num_classes = len(data_df['label'].value_counts())
data_df['label'].value_counts()
df = data_df

# %% [markdown]
# #### Split data into train, valid, test

# %%
train_df, test_df = train_test_split(df, train_size=0.8, random_state=42, stratify=df['label'])

train_df, valid_df = train_test_split(train_df, train_size=0.8, random_state=42, stratify=train_df['label'])

# %%
train_df
# Out:
#                                              image_path             label
# 2760  /root/.cache/kagglehub/datasets/fernando2rad/b...  Neurocitoma T1C+
# 4306  /root/.cache/kagglehub/datasets/fernando2rad/b...        _NORMAL T2
# 4124  /root/.cache/kagglehub/datasets/fernando2rad/b...        _NORMAL T1
# 211   /root/.cache/kagglehub/datasets/fernando2rad/b...  Astrocitoma T1C+
# 2870  /root/.cache/kagglehub/datasets/fernando2rad/b...    Neurocitoma T2
# ...                                                 ...               ...
# 1857  /root/.cache/kagglehub/datasets/fernando2rad/b...   Meningioma T1C+
# 3381  /root/.cache/kagglehub/datasets/fernando2rad/b...     Schwannoma T1
# 1296  /root/.cache/kagglehub/datasets/fernando2rad/b...   Glioblastoma T2
# 4447  /root/.cache/kagglehub/datasets/fernando2rad/b...        _NORMAL T2
# 1358  /root/.cache/kagglehub/datasets/fernando2rad/b...      Granuloma T1
#
# [2866 rows x 2 columns]

# %% [markdown]
# #### ImageDataGenerator

# %%
BATCH_SIZE = 8
image_size = (224, 224)

gen = ImageDataGenerator()

train_gen = gen.flow_from_dataframe(train_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
train_steps = len(train_df) // BATCH_SIZE

valid_gen = gen.flow_from_dataframe(valid_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
val_steps = len(valid_df) // BATCH_SIZE

test_gen = gen.flow_from_dataframe(test_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
test_steps = len(test_df) // BATCH_SIZE
# Out:
# Found 2866 validated image filenames belonging to 44 classes.
# Found 717 validated image filenames belonging to 44 classes.
# Found 895 validated image filenames belonging to 44 classes.

# %% [markdown]
# ### Model Structure

# %%
from tensorflow.keras.layers import (
    GlobalAveragePooling2D,
    GlobalMaxPooling2D,
    Reshape,
    Dense,
    Conv2D,
    Activation,
    Add,
    Multiply,
    Concatenate,
    Lambda
)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import layers

# --------------------------------------------------------
# Channel Attention
# --------------------------------------------------------
def channel_attention(input_feature, ratio=8):

    channel = input_feature.shape[-1]

    shared_layer_one = layers.Dense(
        channel // ratio,
        activation='relu',
        kernel_initializer='he_normal',
        use_bias=True,
        bias_initializer='zeros'
    )

    shared_layer_two = layers.Dense(
        channel,
        kernel_initializer='he_normal',
        use_bias=True,
        bias_initializer='zeros'
    )

    # Average Pool
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)

    # Max Pool
    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)

    # Merge
    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Activation("sigmoid")(cbam_feature)

    return layers.Multiply()([input_feature, cbam_feature])


# --------------------------------------------------------
# Spatial Attention
# --------------------------------------------------------
from tensorflow.keras import layers
from tensorflow import keras

def spatial_attention(input_feature):

    # Average Pool
    avg_pool = layers.Lambda(
        lambda x: keras.ops.mean(x, axis=-1, keepdims=True)
    )(input_feature)

    # Max Pool
    max_pool = layers.Lambda(
        lambda x: keras.ops.max(x, axis=-1, keepdims=True)
    )(input_feature)

    # Concatenate
    concat = layers.Concatenate(axis=-1)([avg_pool, max_pool])

    # Convolution
    cbam_feature = layers.Conv2D(
        filters=1,
        kernel_size=7,
        strides=1,
        padding="same",
        activation="sigmoid",
        kernel_initializer="he_normal",
        use_bias=False,
    )(concat)

    return layers.Multiply()([input_feature, cbam_feature])
# --------------------------------------------------------
# CBAM Block
# --------------------------------------------------------
def cbam_block(input_feature, ratio=8):

    x = channel_attention(input_feature, ratio)
    x = spatial_attention(x)

    return x

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

def build_cbam_vggnet(input_shape=(224, 224, 3), num_classes=44):

    # Backbone
    base_model = VGG16(
        weights=None,
        include_top=False,
        input_shape=input_shape
    )

    # Last feature map from VGG16
    x = base_model.output

    # CBAM
    x = cbam_block(x)

    # Classification Head
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(
        512,
        activation="relu"
    )(x)

    x = layers.Dropout(0.5)(x)

    x = layers.Dense(
        256,
        activation="relu"
    )(x)

    x = layers.Dropout(0.3)(x)

    # 44-class classification
    x = layers.Dense(
        num_classes,
        activation="softmax"
    )(x)

    model = models.Model(
        inputs=base_model.input,
        outputs=x,
        name="CBAM_VGG16"
    )

    return model


model = build_cbam_vggnet()

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "CBAM_VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer_6[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 1, 512) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, 1, 1, 512) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 1, 1, 64)  │     32,832 │ reshape_8[0][0],  │
# │                     │                   │            │ reshape_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1, 1, 512) │     33,280 │ dense_12[0][0],   │
# │                     │                   │            │ dense_12[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 512) │          0 │ dense_13[0][0],   │
# │                     │                   │            │ dense_13[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 1, 1, 512) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 7, 7, 512) │          0 │ block5_pool[0][0… │
# │ (Multiply)          │                   │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 7, 7, 1)   │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 7, 7, 1)   │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 7, 7, 2)   │          0 │ lambda[0][0],     │
# │ (Concatenate)       │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 7, 7, 1)   │         98 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 7, 7, 512) │          0 │ multiply_2[0][0], │
# │ (Multiply)          │                   │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ multiply_3[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 512)       │    262,656 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 256)       │    131,328 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 44)        │     11,308 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,186,190 (57.93 MB)
#  Trainable params: 15,186,190 (57.93 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
num_classes
# Out:
# 44

# %%
model = build_cbam_vggnet()

# %%
plot_model(model, show_shapes=True)

# %%
def create_metrics():
    """
    Creates instances of various metrics for evaluating model performance.

    Returns:
        tuple: A tuple of the metrics: (recall, precision, f1_score, auc, sensitivity, specificity, mcc).
    """
    @tf.function
    def f1_score(y_true, y_pred):
        """
        Calculates the F1 score.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: F1 score.
        """
        tp = true_positive(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        precision = tp / (tp + fp + K.epsilon())
        recall = tp / (tp + fn + K.epsilon())

        return 2 * (precision * recall) / (precision + recall + K.epsilon())

    @tf.function
    def specificity(y_true, y_pred):
        """
        Calculates the specificity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Specificity.
        """
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)

        return tn / (tn + fp + K.epsilon())

    @tf.function
    def sensitivity(y_true, y_pred):
        """
        Calculates the sensitivity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Sensitivity.
        """
        tp = true_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        return tp / (tp + fn + K.epsilon())

    @tf.function
    def mcc(y_true, y_pred):
        """
        Calculates the Matthews correlation coefficient (MCC).

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Matthews correlation coefficient.
        """
        tp = true_positive(y_true, y_pred)
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        numerator = (tp * tn - fp * fn)
        denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

        return numerator / (denominator + K.epsilon())

    @tf.function
    def true_positive(y_true, y_pred):
        """
        Calculates the number of true positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true positives.
        """
        y_pred_pos, _, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_pos)

    @tf.function
    def false_positive(y_true, y_pred):
        """
        Calculates the number of false positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false positives.
        """
        y_pred_pos, _, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_pos)

    @tf.function
    def false_negative(y_true, y_pred):
        """
        Calculates the number of false negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false negatives.
        """
        _, y_pred_neg, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_neg)

    @tf.function
    def true_negative(y_true, y_pred):
        """
        Calculates the number of true negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true negatives.
        """
        _, y_pred_neg, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_neg)

    @tf.function
    def calculate_confusion_matrix(y_true, y_pred):
        """
        Calculates the components of the confusion matrix.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            tuple: A tuple containing the components of the confusion matrix: (y_pred_pos, y_pred_neg, y_pos, y_neg).
        """
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.round(K.clip(y_true, 0, 1))
        y_neg = 1 - y_pos
        return y_pred_pos, y_pred_neg, y_pos, y_neg

    precision_metric = Precision()
    recall_metric = Recall()
    f1_score_metric = f1_score
    specificity_metric = specificity
    sensitivity_metric = sensitivity
    mcc_metric = mcc
    auc_metric = AUC()

    return (
        precision_metric,
        recall_metric,
        f1_score_metric,
        specificity_metric,
        sensitivity_metric,
        mcc_metric,
        auc_metric,
    )

# %%
model = build_cbam_vggnet(
    input_shape=(224, 224, 3),
    num_classes=44
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_826/2069220823.py in <cell line: 0>()
# ----> 1 model = build_cbam_vggnet(
#       2     input_shape=(224, 224, 3),
#       3     num_classes=44
#       4 )
#
# /tmp/ipykernel_826/3488047741.py in build_cbam_vggnet(input_shape, num_classes)
#       4     # Add the CBAM block after each convolutional block
#       5     x = base_model.get_layer('block1_conv2').output
# ----> 6     x = cbam_block(x)
#       7
#       8     x = base_model.get_layer('block2_conv2').output
#
# /tmp/ipykernel_826/2007275036.py in cbam_block(cbam_feature, ratio)
#       4     """
#       5
# ----> 6     cbam_feature = channel_attention(cbam_feature, ratio)
#       7     cbam_feature = spatial_attention(cbam_feature)
#       8     return cbam_feature
#
# /tmp/ipykernel_826/2007275036.py in channel_attention(input_feature, ratio)
#      22                              bias_initializer='zeros')
#      23
# ---> 24     avg_pool = GlobalAveragePooling2D()(input_feature)
#      25     avg_pool = Reshape((1,1,channel))(avg_pool)
#      26     assert avg_pool.shape[1:] == (1,1,channel)
#
# NameError: name 'GlobalAveragePooling2D' is not defined

# %%
metrics= list(create_metrics())
metrics.append("accuracy")

model.compile(
    optimizer = Adam(learning_rate = 5e-4),
    loss = 'categorical_crossentropy',
    metrics = metrics
)

# %%
class TimeCallback(tf.keras.callbacks.Callback):
    """Custom callback to record epoch times and total training time."""

    def on_train_begin(self, logs=None):
        """Initialize training start time and epoch times."""
        self.train_start_time = time.perf_counter()
        self.epoch_times = []

    def on_epoch_begin(self, epoch, logs=None):
        """Record start time of each epoch."""
        self.epoch_start_time = time.perf_counter()

    def on_epoch_end(self, epoch, logs=None):
        """Calculate and store epoch time."""
        epoch_time = time.perf_counter() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

    def on_train_end(self, logs=None):
        """Calculate total training time."""
        self.total_train_time = time.perf_counter() - self.train_start_time

# Create an instance of the TimeCallback
time_callback = TimeCallback()

# %%
#@title Learning rate scheduler

from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

def lr_schedule(epoch,lr):
    if epoch < 13:
        return lr
    else:
        return 0.9*lr


lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
from tensorflow.keras import backend as K

# %%
import tensorflow as tf
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# Automatically get the correct input size
_, H, W, C = model.input_shape

@tf.function
def model_fn(x):
    return model(x)

concrete_func = model_fn.get_concrete_function(
    tf.TensorSpec([1, H, W, C], tf.float32)
)

frozen_func = convert_variables_to_constants_v2(concrete_func)
graph = frozen_func.graph

with graph.as_default():
    flops = tf.compat.v1.profiler.profile(
        graph=graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    )

print("="*60)
print(f"Input Shape : {model.input_shape}")
print(f"Parameters  : {model.count_params():,}")
print(f"Params (M)  : {model.count_params()/1e6:.3f}")
print(f"FLOPs       : {flops.total_float_ops:,}")
print(f"GFLOPs      : {flops.total_float_ops/1e9:.3f}")
print("="*60)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/nn_ops.py:5261: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# ============================================================
# Input Shape : (None, 224, 224, 3)
# Parameters  : 15,186,190
# Params (M)  : 15.186
# FLOPs       : 30,714,139,148
# GFLOPs      : 30.714
# ============================================================

# %%
TOTAL_EPOCHS = 25
start_time = perf_counter()
history = model.fit(
    train_gen,
    epochs=TOTAL_EPOCHS,
    validation_data=valid_gen,
    steps_per_epoch=train_steps,
    validation_steps=val_steps,
    callbacks=[time_callback,lr_scheduler]
)
end_time = perf_counter()
# Out:
# Epoch 1/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.0546 - auc_5: 0.6417 - f1_score: 0.0641 - loss: 4.3095 - mcc: 0.0652 - precision_5: 0.0333 - recall_5: 0.6716 - sensitivity: 0.6723 - specificity: 0.5434 - val_accuracy: 0.0618 - val_auc_5: 0.6971 - val_f1_score: 0.0761 - val_loss: 3.5690 - val_mcc: 0.0923 - val_precision_5: 0.0403 - val_recall_5: 0.6728 - val_sensitivity: 0.6728 - val_specificity: 0.6277 - learning_rate: 5.0000e-04
# Epoch 2/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1250 - auc_5: 0.7858 - f1_score: 0.0845 - loss: 3.4561 - mcc: 0.1160 - precision_5: 0.0448 - recall_5: 0.7500 - sensitivity: 0.7500 - specificity: 0.6279 - val_accuracy: 0.0000e+00 - val_auc_5: 0.6744 - val_f1_score: 0.0755 - val_loss: 4379932.0000 - val_mcc: 0.1043 - val_precision_5: 0.0396 - val_recall_5: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.5488 - learning_rate: 5.0000e-04
# Epoch 3/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0656 - auc_5: 0.6931 - f1_score: 0.0804 - loss: 14.0644 - mcc: 0.1010 - precision_5: 0.0424 - recall_5: 0.6861 - sensitivity: 0.6858 - specificity: 0.6392 - val_accuracy: 0.0815 - val_auc_5: 0.7072 - val_f1_score: 0.0786 - val_loss: 3.9418 - val_mcc: 0.1006 - val_precision_5: 0.0416 - val_recall_5: 0.7079 - val_sensitivity: 0.7079 - val_specificity: 0.6208 - learning_rate: 5.0000e-04
# Epoch 4/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 0.0000e+00 - auc_5: 0.7907 - f1_score: 0.0972 - loss: 3.7004 - mcc: 0.1530 - precision_5: 0.0515 - recall_5: 0.8750 - sensitivity: 0.8750 - specificity: 0.6250 - val_accuracy: 0.0000e+00 - val_auc_5: 0.6116 - val_f1_score: 0.0800 - val_loss: 8631132.0000 - val_mcc: 0.1134 - val_precision_5: 0.0421 - val_recall_5: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.5767 - learning_rate: 5.0000e-04
# Epoch 5/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0773 - auc_5: 0.7018 - f1_score: 0.0780 - loss: 3.9257 - mcc: 0.0974 - precision_5: 0.0414 - recall_5: 0.6861 - sensitivity: 0.6863 - specificity: 0.6304 - val_accuracy: 0.0815 - val_auc_5: 0.7149 - val_f1_score: 0.0791 - val_loss: 3.6139 - val_mcc: 0.1020 - val_precision_5: 0.0419 - val_recall_5: 0.7121 - val_sensitivity: 0.7121 - val_specificity: 0.6212 - learning_rate: 5.0000e-04
# Epoch 6/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.1250 - auc_5: 0.6308 - f1_score: 0.0417 - loss: 3.7145 - mcc: -0.0036 - precision_5: 0.0221 - recall_5: 0.3750 - sensitivity: 0.3750 - specificity: 0.6134 - val_accuracy: 0.2000 - val_auc_5: 0.5019 - val_f1_score: 0.0430 - val_loss: 7623318.5000 - val_mcc: 0.0000e+00 - val_precision_5: 0.0227 - val_recall_5: 0.4000 - val_sensitivity: 0.4000 - val_specificity: 0.6000 - learning_rate: 5.0000e-04
# Epoch 7/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0879 - auc_5: 0.7131 - f1_score: 0.0789 - loss: 3.5918 - mcc: 0.1009 - precision_5: 0.0418 - recall_5: 0.7059 - sensitivity: 0.7060 - specificity: 0.6233 - val_accuracy: 0.0829 - val_auc_5: 0.7191 - val_f1_score: 0.0815 - val_loss: 3.5352 - val_mcc: 0.1042 - val_precision_5: 0.0433 - val_recall_5: 0.6924 - val_sensitivity: 0.6924 - val_specificity: 0.6440 - learning_rate: 5.0000e-04
# Epoch 8/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 0.0000e+00 - auc_5: 0.8052 - f1_score: 0.1176 - loss: 3.4291 - mcc: 0.2017 - precision_5: 0.0625 - recall_5: 1.0000 - sensitivity: 1.0000 - specificity: 0.6512 - val_accuracy: 0.0000e+00 - val_auc_5: 0.6233 - val_f1_score: 0.0941 - val_loss: 3.6783 - val_mcc: 0.1383 - val_precision_5: 0.0500 - val_recall_5: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.6465 - learning_rate: 5.0000e-04
# Epoch 9/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0880 - auc_5: 0.7161 - f1_score: 0.0823 - loss: 3.5264 - mcc: 0.1045 - precision_5: 0.0438 - recall_5: 0.6828 - sensitivity: 0.6822 - specificity: 0.6532 - val_accuracy: 0.0829 - val_auc_5: 0.7217 - val_f1_score: 0.0839 - val_loss: 3.4973 - val_mcc: 0.1063 - val_precision_5: 0.0448 - val_recall_5: 0.6713 - val_sensitivity: 0.6713 - val_specificity: 0.6668 - learning_rate: 5.0000e-04
# Epoch 10/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 138us/step - accuracy: 0.0000e+00 - auc_5: 0.6206 - f1_score: 0.0625 - loss: 3.7618 - mcc: 0.0512 - precision_5: 0.0333 - recall_5: 0.5000 - sensitivity: 0.5000 - specificity: 0.6628 - val_accuracy: 0.0000e+00 - val_auc_5: 0.4884 - val_f1_score: 0.0625 - val_loss: 13106859.0000 - val_mcc: 0.0577 - val_precision_5: 0.0330 - val_recall_5: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.5907 - learning_rate: 5.0000e-04
# Epoch 11/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0797 - auc_5: 0.7175 - f1_score: 0.0834 - loss: 3.5020 - mcc: 0.1050 - precision_5: 0.0445 - recall_5: 0.6677 - sensitivity: 0.6673 - specificity: 0.6667 - val_accuracy: 0.0829 - val_auc_5: 0.7225 - val_f1_score: 0.0841 - val_loss: 3.4838 - val_mcc: 0.1068 - val_precision_5: 0.0449 - val_recall_5: 0.6728 - val_sensitivity: 0.6728 - val_specificity: 0.6668 - learning_rate: 5.0000e-04
# Epoch 12/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 144us/step - accuracy: 0.0000e+00 - auc_5: 0.7820 - f1_score: 0.0937 - loss: 3.3472 - mcc: 0.1316 - precision_5: 0.0500 - recall_5: 0.7500 - sensitivity: 0.7500 - specificity: 0.6686 - val_accuracy: 0.0000e+00 - val_auc_5: 0.6860 - val_f1_score: 0.0750 - val_loss: 3.6021 - val_mcc: 0.0834 - val_precision_5: 0.0400 - val_recall_5: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.6651 - learning_rate: 5.0000e-04
# Epoch 13/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0902 - auc_5: 0.7223 - f1_score: 0.0841 - loss: 33.9748 - mcc: 0.1068 - precision_5: 0.0449 - recall_5: 0.6736 - sensitivity: 0.6732 - specificity: 0.6666 - val_accuracy: 0.0829 - val_auc_5: 0.7214 - val_f1_score: 0.0839 - val_loss: 44.1143 - val_mcc: 0.1062 - val_precision_5: 0.0447 - val_recall_5: 0.6713 - val_sensitivity: 0.6713 - val_specificity: 0.6664 - learning_rate: 5.0000e-04
# Epoch 14/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 150us/step - accuracy: 0.0000e+00 - auc_5: 0.6119 - f1_score: 0.0469 - loss: 3.7883 - mcc: 0.0110 - precision_5: 0.0250 - recall_5: 0.3750 - sensitivity: 0.3750 - specificity: 0.6599 - val_accuracy: 0.0000e+00 - val_auc_5: 0.7465 - val_f1_score: 0.0750 - val_loss: 3.4826 - val_mcc: 0.0834 - val_precision_5: 0.0400 - val_recall_5: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.6651 - learning_rate: 4.5000e-04
# Epoch 15/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0888 - auc_5: 0.7284 - f1_score: 0.0853 - loss: 45.1504 - mcc: 0.1099 - precision_5: 0.0454 - recall_5: 0.6821 - sensitivity: 0.6833 - specificity: 0.6664 - val_accuracy: 0.0801 - val_auc_5: 0.7103 - val_f1_score: 0.0822 - val_loss: 470.2481 - val_mcc: 0.1024 - val_precision_5: 0.0438 - val_recall_5: 0.6629 - val_sensitivity: 0.6629 - val_specificity: 0.6632 - learning_rate: 4.0500e-04
# Epoch 16/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - accuracy: 0.0000e+00 - auc_5: 0.5131 - f1_score: 0.0312 - loss: 4.0562 - mcc: -0.0292 - precision_5: 0.0167 - recall_5: 0.2500 - sensitivity: 0.2500 - specificity: 0.6570 - val_accuracy: 0.2000 - val_auc_5: 0.7372 - val_f1_score: 0.1000 - val_loss: 3.3928 - val_mcc: 0.1477 - val_precision_5: 0.0533 - val_recall_5: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.6698 - learning_rate: 3.6450e-04
# Epoch 17/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 29s 79ms/step - accuracy: 0.0765 - auc_5: 0.7150 - f1_score: 0.0825 - loss: 272.4794 - mcc: 0.1028 - precision_5: 0.0440 - recall_5: 0.6644 - sensitivity: 0.6628 - specificity: 0.6642 - val_accuracy: 0.0801 - val_auc_5: 0.7224 - val_f1_score: 0.0839 - val_loss: 3.4796 - val_mcc: 0.1063 - val_precision_5: 0.0448 - val_recall_5: 0.6713 - val_sensitivity: 0.6713 - val_specificity: 0.6668 - learning_rate: 3.2805e-04
# Epoch 18/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step - accuracy: 0.0000e+00 - auc_5: 0.6948 - f1_score: 0.0937 - loss: 3.5490 - mcc: 0.1316 - precision_5: 0.0500 - recall_5: 0.7500 - sensitivity: 0.7500 - specificity: 0.6686 - val_accuracy: 0.4000 - val_auc_5: 0.8070 - val_f1_score: 0.1000 - val_loss: 3.1849 - val_mcc: 0.1477 - val_precision_5: 0.0533 - val_recall_5: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.6698 - learning_rate: 2.9525e-04
# Epoch 19/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0800 - auc_5: 0.7135 - f1_score: 0.0833 - loss: 3.5002 - mcc: 0.1046 - precision_5: 0.0444 - recall_5: 0.6660 - sensitivity: 0.6661 - specificity: 0.6667 - val_accuracy: 0.0829 - val_auc_5: 0.7227 - val_f1_score: 0.0841 - val_loss: 3.4779 - val_mcc: 0.1068 - val_precision_5: 0.0449 - val_recall_5: 0.6728 - val_sensitivity: 0.6728 - val_specificity: 0.6668 - learning_rate: 2.6572e-04
# Epoch 20/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 135us/step - accuracy: 0.2500 - auc_5: 0.8154 - f1_score: 0.0937 - loss: 3.1816 - mcc: 0.1316 - precision_5: 0.0500 - recall_5: 0.7500 - sensitivity: 0.7500 - specificity: 0.6686 - val_accuracy: 0.0000e+00 - val_auc_5: 0.7814 - val_f1_score: 0.0750 - val_loss: 3.3712 - val_mcc: 0.0834 - val_precision_5: 0.0400 - val_recall_5: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.6651 - learning_rate: 2.3915e-04
# Epoch 21/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 78ms/step - accuracy: 0.0743 - auc_5: 0.7179 - f1_score: 0.0830 - loss: 3.4919 - mcc: 0.1040 - precision_5: 0.0442 - recall_5: 0.6631 - sensitivity: 0.6642 - specificity: 0.6666 - val_accuracy: 0.0829 - val_auc_5: 0.7233 - val_f1_score: 0.0839 - val_loss: 3.4763 - val_mcc: 0.1063 - val_precision_5: 0.0448 - val_recall_5: 0.6713 - val_sensitivity: 0.6713 - val_specificity: 0.6668 - learning_rate: 2.1523e-04
# Epoch 22/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 0.1250 - auc_5: 0.6410 - f1_score: 0.0781 - loss: 3.6987 - mcc: 0.0914 - precision_5: 0.0417 - recall_5: 0.6250 - sensitivity: 0.6250 - specificity: 0.6657 - val_accuracy: 0.0000e+00 - val_auc_5: 0.6907 - val_f1_score: 0.1000 - val_loss: 3.5726 - val_mcc: 0.1477 - val_precision_5: 0.0533 - val_recall_5: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.6698 - learning_rate: 1.9371e-04
# Epoch 23/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0855 - auc_5: 0.7229 - f1_score: 0.0858 - loss: 3.4717 - mcc: 0.1112 - precision_5: 0.0457 - recall_5: 0.6855 - sensitivity: 0.6866 - specificity: 0.6671 - val_accuracy: 0.0815 - val_auc_5: 0.7237 - val_f1_score: 0.0841 - val_loss: 3.4758 - val_mcc: 0.1068 - val_precision_5: 0.0449 - val_recall_5: 0.6728 - val_sensitivity: 0.6728 - val_specificity: 0.6668 - learning_rate: 1.7434e-04
# Epoch 24/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.0000e+00 - auc_5: 0.8169 - f1_score: 0.0937 - loss: 3.2321 - mcc: 0.1316 - precision_5: 0.0500 - recall_5: 0.7500 - sensitivity: 0.7500 - specificity: 0.6686 - val_accuracy: 0.2000 - val_auc_5: 0.6395 - val_f1_score: 0.0750 - val_loss: 3.6241 - val_mcc: 0.0834 - val_precision_5: 0.0400 - val_recall_5: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.6651 - learning_rate: 1.5691e-04
# Epoch 25/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 28s 79ms/step - accuracy: 0.0876 - auc_5: 0.7252 - f1_score: 0.0845 - loss: 3.4681 - mcc: 0.1077 - precision_5: 0.0450 - recall_5: 0.6757 - sensitivity: 0.6758 - specificity: 0.6669 - val_accuracy: 0.0829 - val_auc_5: 0.7226 - val_f1_score: 0.0837 - val_loss: 3.4783 - val_mcc: 0.1059 - val_precision_5: 0.0447 - val_recall_5: 0.6699 - val_sensitivity: 0.6699 - val_specificity: 0.6667 - learning_rate: 1.4121e-04

# %%
execution_time_parts = []
avg_time_parts = []

for unit in [(3600, 'hours'), (60, 'minutes'), (1, 'seconds'), (0.001, 'milliseconds')]:
    total_value = int(time_callback.total_train_time // unit[0])
    avg_value = int(np.mean(time_callback.epoch_times) // unit[0])

    if total_value > 0 or unit[0] == 0.001:
        execution_time_parts.append((total_value, unit[1]))
    if avg_value > 0 or unit[0] == 0.001:
        avg_time_parts.append((avg_value, unit[1]))

    time_callback.total_train_time -= total_value * unit[0]
    time_callback.epoch_times = [time - avg_value * unit[0] for time in time_callback.epoch_times]

execution_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in execution_time_parts if value > 0
])

avg_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in avg_time_parts if value > 0
])

print(f"Model training took {execution_time_string}")
print(f"Average time per epoch: {avg_time_string}")
# Out:
# Model training took 06 minutes, 24 seconds, 545 milliseconds
# Average time per epoch: 15 seconds, 364 milliseconds

# %%
_ = model.evaluate(test_gen, steps = test_steps)
# Out:
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.0771 - auc_5: 0.7216 - f1_score: 0.0836 - loss: 3.4829 - mcc: 0.1056 - precision_5: 0.0446 - recall_5: 0.6690 - sensitivity: 0.6690 - specificity: 0.6667

# %%
def plot_metrics(hist, metric_name_list):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        hist: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot

    Returns:
        None
    """
    num_metrics = len(metric_name_list)

    figure, axes = plt.subplots(num_metrics, figsize=(10, 6 * num_metrics))

    rng = range(1, len(hist.history[metric_name_list[0]]) + 1)

    for ax, metric_n in zip(axes, metric_name_list):
        metric = hist.history[metric_n]
        v_metric = hist.history[f"val_{metric_n}"]

        ax.plot(rng, metric, label=metric_n)
        ax.plot(rng, v_metric, label=f"val_{metric_n}")
        ax.legend()
        ax.set_xlabel("Epochs")

        if metric_n in ("auc", "mcc"):
            ax.set_ylabel(metric_n.upper())
            ax.set_title(metric_n.upper() + " vs Epochs")
        else:
            ax.set_ylabel(metric_n.capitalize())
            ax.set_title(metric_n.capitalize() + " vs Epochs")

        max_loss = max(max(metric), max(v_metric))
        min_loss = min(min(metric), min(v_metric))
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()

    plt.show()

# %%
metric_names = ["loss", "accuracy","f1_score",
                "specificity", "sensitivity", "mcc"]
plot_metrics(history, metric_names)

# %%
def generate_classification_report(model, test_generator, test_steps, batch_size, target_names):
    """
    Generate a classification report, accuracy, and number of errors for a given model and test generator.

    Args:
        model (object): The trained model.
        test_generator (object): The test data generator.
        test_steps (int): The number of steps to iterate over the test generator.
        batch_size (int): The batch size for generating predictions.
        target_names (list): List of target class names for the classification report.

    Returns:
        tuple: A tuple containing true labels, predicted labels, and the classification report.
    """
    predicted_labels = []
    true_labels = []

    for i in range(test_steps):
        batch_data, batch_true_labels = next(test_generator)

        batch_predicted_labels = model.predict_on_batch(batch_data)
        batch_predicted_labels = np.argmax(batch_predicted_labels, axis=1)

        predicted_labels.extend(batch_predicted_labels)
        true_labels.extend(batch_true_labels)

    true_labels = np.array(true_labels)

    if len(true_labels[0]) > 1:
        true_labels = np.argmax(true_labels, axis=1)

    report = classification_report(
        true_labels,
        predicted_labels,
        target_names=target_names,
        digits=4,
        zero_division=1
    )

    accuracy = accuracy_score(true_labels, predicted_labels)
    num_errors = np.sum(true_labels != predicted_labels)

    print(report)
    print(f'There were {num_errors} errors in {len(predicted_labels)} tests for an accuracy of {accuracy*100:6.2f}')

    return true_labels, predicted_labels

# %%
true_labels, predicted_labels = generate_classification_report(
    model, test_gen, test_steps, BATCH_SIZE, df["label"].unique()
)
# Out:
#                         precision    recall  f1-score   support
#
#         Astrocitoma T1     1.0000    0.0000    0.0000        35
#       Astrocitoma T1C+     1.0000    0.0000    0.0000        46
#         Astrocitoma T2     1.0000    0.0000    0.0000        34
#           Carcinoma T1     1.0000    0.0000    0.0000        13
#         Carcinoma T1C+     1.0000    0.0000    0.0000        22
#           Carcinoma T2     1.0000    0.0000    0.0000        15
#          Ependimoma T1     1.0000    0.0000    0.0000         9
#        Ependimoma T1C+     1.0000    0.0000    0.0000        10
#          Ependimoma T2     1.0000    0.0000    0.0000        11
#       Ganglioglioma T1     1.0000    0.0000    0.0000         4
#     Ganglioglioma T1C+     1.0000    0.0000    0.0000         3
#       Ganglioglioma T2     1.0000    0.0000    0.0000         5
#           Germinoma T1     1.0000    0.0000    0.0000         5
#         Germinoma T1C+     1.0000    0.0000    0.0000         8
#           Germinoma T2     1.0000    0.0000    0.0000         7
#        Glioblastoma T1     1.0000    0.0000    0.0000        11
#      Glioblastoma T1C+     1.0000    0.0000    0.0000        19
#        Glioblastoma T2     1.0000    0.0000    0.0000        11
#           Granuloma T1     1.0000    0.0000    0.0000         6
#         Granuloma T1C+     1.0000    0.0000    0.0000         6
#           Granuloma T2     1.0000    0.0000    0.0000         3
#      Meduloblastoma T1     1.0000    0.0000    0.0000         4
#    Meduloblastoma T1C+     1.0000    0.0000    0.0000        13
#      Meduloblastoma T2     1.0000    0.0000    0.0000         8
#          Meningioma T1     1.0000    0.0000    0.0000        54
#        Meningioma T1C+     0.0827    1.0000    0.1527        74
#          Meningioma T2     1.0000    0.0000    0.0000        47
#         Neurocitoma T1     1.0000    0.0000    0.0000        26
#       Neurocitoma T1C+     1.0000    0.0000    0.0000        45
#         Neurocitoma T2     1.0000    0.0000    0.0000        21
#   Oligodendroglioma T1     1.0000    0.0000    0.0000        17
# Oligodendroglioma T1C+     1.0000    0.0000    0.0000        14
#   Oligodendroglioma T2     1.0000    0.0000    0.0000        13
#            Papiloma T1     1.0000    0.0000    0.0000        13
#          Papiloma T1C+     1.0000    0.0000    0.0000        22
#            Papiloma T2     1.0000    0.0000    0.0000        13
#          Schwannoma T1     1.0000    0.0000    0.0000        30
#        Schwannoma T1C+     1.0000    0.0000    0.0000        39
#          Schwannoma T2     1.0000    0.0000    0.0000        25
#         Tuberculoma T1     1.0000    0.0000    0.0000         6
#       Tuberculoma T1C+     1.0000    0.0000    0.0000        17
#         Tuberculoma T2     1.0000    0.0000    0.0000         7
#             _NORMAL T1     1.0000    0.0000    0.0000        50
#             _NORMAL T2     1.0000    0.0000    0.0000        54
#
#               accuracy                         0.0827       895
#              macro avg     0.9792    0.0227    0.0035       895
#           weighted avg     0.9242    0.0827    0.0126       895
#
# There were 821 errors in 895 tests for an accuracy of   8.27

# %%
def confusion_matrix(true_labels, predicted_labels, num_classes):
    """
    Compute the confusion matrix.

    Args:
        true_labels (list or numpy.ndarray): Array-like object of true labels.
        predicted_labels (list or numpy.ndarray): Array-like object of predicted labels.
        num_classes (int): Number of classes.

    Returns:
        numpy.ndarray: Confusion matrix.
    """
    cm = np.zeros((num_classes, num_classes), dtype=int)
    np.add.at(cm, (true_labels, predicted_labels), 1)
    return cm

# %%
cm = confusion_matrix(true_labels, predicted_labels, num_classes)

plt.figure(figsize=(15, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels= df["label"].unique(), yticklabels= df["label"].unique())

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
